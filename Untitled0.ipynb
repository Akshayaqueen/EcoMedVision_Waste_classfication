# %%
# 1) create workspace folders
# !mkdir -p /content/dataset/medical /content/dataset/recyclable

# 2) unzip your downloaded zip files (change names to yours)
# !unzip -q "/content/archive (1).zip" -d /content/archive3
# !unzip -q "/content/archive.zip" -d /content/archive2

# 3) inspect extracted structure (quick check)
# !find /content/archive3 -maxdepth 2 -type d -print
# !find /content/archive2 -maxdepth 2 -type d -print
# Out:
# /content/archive3
# /content/archive3/dataset-resized
# /content/archive3/dataset-resized/trash
# /content/archive3/dataset-resized/paper
# /content/archive3/dataset-resized/metal
# /content/archive3/dataset-resized/plastic
# /content/archive3/dataset-resized/glass
# /content/archive3/dataset-resized/cardboard
# /content/archive2
# /content/archive2/Medical Waste 4.0
# /content/archive2/Medical Waste 4.0/Medical Waste 4.0

# %%
import os, shutil

# Replace these source paths after you inspect the archive folders
recyclable_src = "/content/archive3/dataset-resized"    # contains cardboard, glass, metal, plastic, paper, trash
medical_src = "/content/archive2/Medical Waste 4.0"       # replace with the real folder discovered

dst_med = "/content/dataset/medical"
dst_rec = "/content/dataset/recyclable"

# copy recyclables: all subfolders into dst_rec
for sub in os.listdir(recyclable_src):
    p = os.path.join(recyclable_src, sub)
    if os.path.isdir(p):
        for f in os.listdir(p):
            shutil.copy(os.path.join(p, f), dst_rec)

# copy medical images (if medical_src contains images directly)
for f in os.listdir(medical_src):
    fp = os.path.join(medical_src, f)
    if os.path.isfile(fp):
        shutil.copy(fp, dst_med)

# quick counts
print("medical:", len(os.listdir(dst_med)))
print("recyclable:", len(os.listdir(dst_rec)))
# Out:
# medical: 1
# recyclable: 2527

# %%
# !pip install -q split-folders

import splitfolders

input_folder = "/content/dataset"
output_folder = "/content/split_data"
splitfolders.ratio(input_folder, output=output_folder, seed=42, ratio=(0.8, 0.2))
# Out:
# Copying files: 2528 files [00:00, 8018.69 files/s]

# %%
import tensorflow as tf

IMG_SIZE = (224,224)
BATCH = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/split_data/train",
    image_size=IMG_SIZE,
    batch_size=BATCH,
    label_mode='binary',
    shuffle=True
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/split_data/val",
    image_size=IMG_SIZE,
    batch_size=BATCH,
    label_mode='binary',
    shuffle=False
)

# performance tips
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks

IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.MobileNetV2(
    input_shape=IMG_SHAPE,
    include_top=False,
    weights='imagenet'
)
base_model.trainable = False  # freeze initially

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dropout(0.3),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()

# Callbacks
early = callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
ckpt_path = "/content/models/ecomedvision_best.h5"
checkpoint = callbacks.ModelCheckpoint(ckpt_path, save_best_only=True, monitor='val_loss')

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=12,
    callbacks=[early, checkpoint]
)
# Out:
# Found 2021 files belonging to 2 classes.
# Found 506 files belonging to 2 classes.
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ...

# %%
base_model.trainable = True
# unfreeze last N layers
for layer in base_model.layers[:-50]:
    layer.trainable = False

model.compile(optimizer=tf.keras.optimizers.Adam(1e-5), loss='binary_crossentropy', metrics=['accuracy'])
history_ft = model.fit(train_ds, validation_data=val_ds, epochs=8, callbacks=[early, checkpoint])
model.save("/content/models/ecomedvision_model.h5")
model.save("/content/models/ecomedvision_model.h5")
# Out:
# Epoch 1/8
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 42s 330ms/step - accuracy: 1.0000 - loss: 7.9108e-05 - val_accuracy: 1.0000 - val_loss: 2.5446e-05
# Epoch 2/8
# 63/64 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 1.8624e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 1.0000 - loss: 1.8630e-05 - val_accuracy: 1.0000 - val_loss: 2.3684e-05
# Epoch 3/8
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 1.0000 - loss: 9.2060e-06 - val_accuracy: 1.0000 - val_loss: 2.4049e-05
# Epoch 4/8
# 63/64 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 7.0381e-06
# ...

# %%
model.save("/content/models/ecomedvision_model.keras")
model.save("/content/models/ecomedvision_model.keras")

# %%
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt

def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(predictions[0])
        class_channel = predictions[:, pred_index]

    grads = tape.gradient(class_channel, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0,1,2))
    conv_outputs = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = np.maximum(heatmap, 0) / (tf.math.reduce_max(heatmap) + 1e-8)
    return heatmap.numpy()

def overlay_heatmap(img_path, heatmap, alpha=0.4, cmap='jet'):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
    heatmap = np.uint8(255 * heatmap)
    heatmap_color = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    overlayed = heatmap_color * alpha + img
    overlayed = np.uint8(overlayed / overlayed.max() * 255)
    return overlayed

# Usage example:
# img = tf.keras.preprocessing.image.load_img(PATH, target_size=(224,224))
# x = tf.keras.preprocessing.image.img_to_array(img)[None,...]/255.0
# heatmap = make_gradcam_heatmap(x, model, last_conv_layer_name='Conv_1')
# overlay = overlay_heatmap(PATH, heatmap)
# plt.imshow(overlay); plt.axis('off')

# %%
print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)

print("Linear Regression R2:", lr_r2)
print("Random Forest R2:", rf_r2)
print("XGBoost R2:", xgb_r2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2395815104.py in <cell line: 0>()
# ----> 1 print("Train shape:", X_train.shape)
#       2 print("Test shape:", X_test.shape)
#       3
#       4 print("Linear Regression R2:", lr_r2)
#       5 print("Random Forest R2:", rf_r2)
#
# NameError: name 'X_train' is not defined

# %%
# %whos
# Out:
# Variable               Type                Data/Info
# ----------------------------------------------------
# AUTOTUNE               int                 -1
# BATCH                  int                 32
# IMG_SHAPE              tuple               n=3
# IMG_SIZE               tuple               n=2
# base_model             Functional          <Functional name=mobilene<...>tv2_1.00_224, built=True>
# callbacks              module              <module 'keras.callbacks'<...>s/callbacks/__init__.py'>
# checkpoint             ModelCheckpoint     <keras.src.callbacks.mode<...>object at 0x7d7390bf20f0>
# ckpt_path              str                 /content/models/ecomedvision_best.h5
# cv2                    module              <module 'cv2' (<google.co<...>ject at 0x7d73abe4f7a0>)>
# dst_med                str                 /content/dataset/medical
# dst_rec                str                 /content/dataset/recyclable
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train', 'Val'])
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.legend(['Train', 'Val'])
plt.show()

# %%
# !ls /content/dataset/medical | head
# Out:
# readme.txt

# %%
# !ls -R /content/dataset/medical
# Out:
# /content/dataset/medical:
# readme.txt

# %%
import shutil, os

src = "/content/archive2/Medical Waste 4.0"
dst = "/content/dataset/medical"

for folder in os.listdir(src):
    src_path = os.path.join(src, folder)
    if os.path.isdir(src_path):
        print("Copying:", folder)
        shutil.copytree(src_path, os.path.join(dst, folder), dirs_exist_ok=True)

print("✅ All medical images copied correctly!")
# Out:
# Copying: medical_cap
# Copying: glove_single_nitrile
# Copying: glove_pair_latex
# Copying: test_tube
# Copying: .ipynb_checkpoints
# Copying: glove_pair_nitrile
# Copying: medical_glasses
# Copying: shoe_cover_pair
# Copying: shoe_cover_single
# Copying: glove_pair_surgery
# Copying: urine_bag
# Copying: glove_single_surgery
# Copying: gauze
# Copying: glove_single_latex
# ✅ All medical images copied correctly!

# %%
# !ls /content/dataset/medical
# Out:
# gauze		    glove_single_latex	  medical_glasses    test_tube
# glove_pair_latex    glove_single_nitrile  readme.txt	     urine_bag
# glove_pair_nitrile  glove_single_surgery  shoe_cover_pair
# glove_pair_surgery  medical_cap		  shoe_cover_single

# %%
# !find /content/dataset/medical -type f | head
# !find /content/dataset/recyclable -type f | head
# !find /content/dataset/medical -type f | wc -l
# !find /content/dataset/recyclable -type f | wc -l
# Out:
# /content/dataset/medical/medical_cap/1671104014028_r.png
# /content/dataset/medical/medical_cap/1671104072061_l.png
# /content/dataset/medical/medical_cap/1671104146068_l.png
# /content/dataset/medical/medical_cap/1671104072061.jpeg
# /content/dataset/medical/medical_cap/1671104208836_l.png
# /content/dataset/medical/medical_cap/1671104017029.jpeg
# /content/dataset/medical/medical_cap/1671104021632_r.png
# /content/dataset/medical/medical_cap/1671104061354.jpeg
# /content/dataset/medical/medical_cap/1671104046581.jpeg
# /content/dataset/medical/medical_cap/1671104248992_r.png
# /content/dataset/recyclable/glass147.jpg
# /content/dataset/recyclable/paper40.jpg
# /content/dataset/recyclable/cardboard41.jpg
# /content/dataset/recyclable/metal37.jpg
# /content/dataset/recyclable/paper178.jpg
# /content/dataset/recyclable/metal361.jpg
# /content/dataset/recyclable/plastic320.jpg
# /content/dataset/recyclable/paper85.jpg
# /content/dataset/recyclable/plastic162.jpg
# ...

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# Paths
dataset_dir = '/content/dataset'
train_dir = '/content/train'
test_dir = '/content/test'

# Create train and test directories
for category in ['medical', 'recyclable']:
    os.makedirs(os.path.join(train_dir, category), exist_ok=True)
    os.makedirs(os.path.join(test_dir, category), exist_ok=True)

# Split function
def split_data(category, test_size=0.2):
    category_path = os.path.join(dataset_dir, category)
    all_images = []
    # Gather all image paths
    for root, _, files in os.walk(category_path):
        for file in files:
            if file.lower().endswith(('.jpg', '.png', '.jpeg')):
                all_images.append(os.path.join(root, file))

    train_images, test_images = train_test_split(all_images, test_size=test_size, random_state=42)

    # Copy images to train folder
    for img in train_images:
        shutil.copy(img, os.path.join(train_dir, category))
    # Copy images to test folder
    for img in test_images:
        shutil.copy(img, os.path.join(test_dir, category))

# Split both categories
split_data('medical')
split_data('recyclable')

print("✅ Train-test split done!")
# Out:
# ✅ Train-test split done!

# %%
import os

def count_images(folder):
    for category in ['medical', 'recyclable']:
        path = os.path.join(folder, category)
        num = len([f for f in os.listdir(path) if f.lower().endswith(('.jpg', '.png', '.jpeg'))])
        print(f"{folder}/{category}: {num} images")

print("📊 Train images count:")
count_images('/content/train')

print("\n📊 Test images count:")
count_images('/content/test')
# Out:
# 📊 Train images count:
# /content/train/medical: 3396 images
# /content/train/recyclable: 2021 images
#
# 📊 Test images count:
# /content/test/medical: 849 images
# /content/test/recyclable: 506 images

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Image parameters
IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 32

# Data augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1./255,           # normalize pixel values
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Only rescale for testing
test_datagen = ImageDataGenerator(rescale=1./255)

# Load training data
train_generator = train_datagen.flow_from_directory(
    '/content/train',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='binary'  # use 'categorical' if >2 classes
)

# Load testing data
test_generator = test_datagen.flow_from_directory(
    '/content/test',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='binary'
)

print("✅ Data loaders ready!")
# Out:
# Found 5417 images belonging to 2 classes.
# Found 1355 images belonging to 2 classes.
# ✅ Data loaders ready!

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# CNN Model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),  # prevent overfitting
    Dense(1, activation='sigmoid')  # binary classification
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
EPOCHS = 15

history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=test_generator
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training & validation loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

test_loss, test_acc = model.evaluate(test_generator)
print(f"✅ Test Accuracy: {test_acc*100:.2f}%")
print(f"✅ Test Loss: {test_loss:.4f}")
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 156ms/step - accuracy: 0.9910 - loss: 0.0329
# ✅ Test Accuracy: 99.11%
# ✅ Test Loss: 0.0379

# %%
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.preprocessing import image
import os
import random

# --- 1️⃣ Sample images from dataset ---
def plot_sample_images(folder, category, n=3):
    category_path = os.path.join(folder, category)
    imgs = random.sample(os.listdir(category_path), n)
    for i, img_name in enumerate(imgs):
        img_path = os.path.join(category_path, img_name)
        img = image.load_img(img_path, target_size=(100,100))
        plt.subplot(2,3,i+1)
        plt.imshow(img)
        plt.title(f"{category}")
        plt.axis('off')

plt.figure(figsize=(12,8))
plot_sample_images('/content/train', 'medical')
plot_sample_images('/content/train', 'recyclable')
plt.suptitle("🩺 Medical vs 🚮 Recyclable Sample Images", fontsize=16)
plt.show()

# --- 2️⃣ Accuracy & Loss plots ---
plt.figure(figsize=(12,5))

# Accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.suptitle("📊 Training Performance", fontsize=16)
plt.show()

# --- 3️⃣ Test predictions on few images ---
test_imgs = random.sample(os.listdir('/content/test/medical'), 2) + random.sample(os.listdir('/content/test/recyclable'), 2)
plt.figure(figsize=(10,5))

for i, img_name in enumerate(test_imgs):
    img_path = '/content/test/medical/' + img_name if i<2 else '/content/test/recyclable/' + img_name
    img = image.load_img(img_path, target_size=(224,224))
    img_array = image.img_to_array(img)/255.0
    img_array = np.expand_dims(img_array, axis=0)

    pred = model.predict(img_array)[0][0]
    label = "Recyclable" if pred>0.5 else "Medical"

    plt.subplot(2,2,i+1)
    plt.imshow(img)
    plt.title(f"Predicted: {label}\nConfidence: {pred:.2f}")
    plt.axis('off')

plt.suptitle("🧪 Sample Predictions", fontsize=16)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129658 (\N{STETHOSCOPE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128686 (\N{PUT LITTER IN ITS PLACE SYMBOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 765ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129514 (\N{TEST TUBE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
